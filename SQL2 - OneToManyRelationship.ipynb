# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = '3306'
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user = user,
    password = password,
    db = database,
    charset = 'utf8mb4')

def run(sql):
    df=pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ### 1. Report the account representative for each customer.

# %%
run("""
select customerName, concat(firstname,' ',lastname)as employeeName
from customers c join employees e 
on e.employeeNumber = c.salesRepEmployeeNumber
""")
# Out:
#                           customerName     employeeName
# 0         Mini Gifts Distributors Ltd.  Leslie Jennings
# 1                      Mini Wheels Co.  Leslie Jennings
# 2                 Technics Stores Inc.  Leslie Jennings
# 3             Corporate Gift Ideas Co.  Leslie Jennings
# 4            The Sharp Gifts Warehouse  Leslie Jennings
# 5             Signal Collectibles Ltd.  Leslie Jennings
# 6                   Signal Gift Stores  Leslie Thompson
# 7                    Toys4GrownUps.com  Leslie Thompson
# 8                    Boards & Toys Co.  Leslie Thompson
# 9         Collectable Mini Designs Co.  Leslie Thompson
# 10          Men 'R' US Retailers, Ltd.  Leslie Thompson
# 11         West Coast Collectables Co.  Leslie Thompson
# 12          Cambridge Collectables Co.   Julie Firrelli
# 13            Online Mini Collectables   Julie Firrelli
# 14                 Mini Creations Ltd.   Julie Firrelli
# 15             Classic Gift Ideas, Inc   Julie Firrelli
# ...

# %% [markdown]
# ### 2. Report total payments for Atelier graphique.

# %%
run("""
select customerName, sum(amount)
from customers join payments
using (customerNumber)
""")
# Out:
#         customerName  sum(amount)
# 0  Atelier graphique   8853839.23

# %% [markdown]
# ### 3. Report the total payments by date

# %%
run("""
select paymentDate, sum(amount)
from payments
group by paymentDate
""")
# Out:
#     paymentDate  sum(amount)
# 0    2003-01-16     10223.83
# 1    2003-01-28     10549.01
# 2    2003-01-30      5494.78
# 3    2003-02-16     50218.95
# 4    2003-02-20     53959.21
# 5    2003-02-25     40206.20
# 6    2003-03-02     52151.81
# 7    2003-03-09     51001.22
# 8    2003-03-12     22292.62
# 9    2003-03-20     25833.14
# 10   2003-03-27     48425.69
# 11   2003-04-09     24212.79
# 12   2003-04-11     11044.30
# 13   2003-04-16     21665.98
# 14   2003-04-19      1627.56
# 15   2003-04-20     33383.14
# 16   2003-04-22     44380.15
# 17   2003-05-09      3101.40
# 18   2003-05-12     35826.33
# 19   2003-05-20     45864.03
# 20   2003-05-21     16700.47
# 21   2003-05-25     50824.66
# 22   2003-05-31      7565.08
# 23   2003-06-05     14571.44
# 24   2003-06-06     32641.98
# 25   2003-06-13     57131.92
# 26   2003-06-18     58841.35
# 27   2003-06-25     17032.29
# 28   2003-07-05      2880.00
# 29   2003-07-06      6036.96
# ..          ...          ...
# ...

# %% [markdown]
# ### 4. Report the products that have not been sold.

# %%
#SOLD : ketika pembeli telah melakukan pembayaran.

# %%
run("""
select productCode, productName, orderNumber, customerNumber, customerName, checkNumber
from products 
left join orderdetails using (productcode)
left join orders using (ordernumber)
left join customers using (customernumber)
left join payments using (customernumber)
where checknumber is null
""")
# Out:
#   productCode        productName orderNumber customerNumber customerName  \
# 0    S18_3233  1985 Toyota Supra        None           None         None
#
#   checkNumber
# 0        None

# %% [markdown]
# ### 5. List the amount paid by each customer.

# %%
run("""
select customerName, sum(amount) as total
from customers join payments using (customerNumber)
group by customerNumber
""")
# Out:
#                           customerName      total
# 0                    Atelier graphique   22314.36
# 1                   Signal Gift Stores   80180.98
# 2           Australian Collectors, Co.  180585.07
# 3                    La Rochelle Gifts  116949.68
# 4                   Baane Mini Imports  104224.79
# 5         Mini Gifts Distributors Ltd.  584188.24
# 6                 Blauer See Auto, Co.   75937.76
# 7                      Mini Wheels Co.   66710.56
# 8                    Land of Toys Inc.  107639.94
# 9               Euro+ Shopping Channel  715738.98
# 10            Volvo Model Replicas, Co   43680.65
# 11            Danish Wholesale Imports  107446.50
# 12              Saveley & Henriot, Co.  130305.35
# 13             Dragon Souveniers, Ltd.  156251.03
# 14                  Muscle Machine Inc  177913.95
# 15               Diecast Classics Inc.   98509.25
# 16                Technics Stores Inc.  104545.22
# 17                    Handji Gifts& Co  105420.57
# ...

# %% [markdown]
# ### 6. How many orders have been placed by Herkku Gifts?

# %%
run("""
select customerName, orderNumber, status
from customers join orders using (customerNumber)
where customerName = 'Herkku Gifts'
""")
# Out:
#    customerName  orderNumber   status
# 0  Herkku Gifts        10181  Shipped
# 1  Herkku Gifts        10188  Shipped
# 2  Herkku Gifts        10289  Shipped

# %%
run("""
select count(*)
from customers join orders using (customerNumber)
where customerName = 'Herkku Gifts'
""")
# Out:
#    count(*)
# 0         3

# %% [markdown]
# ### 7. Who are the employees in Boston?

# %%
run("""
select concat(firstName,' ', lastname) as employeeName
from employees join offices using (officecode)
where offices.city = 'boston'
""")
# Out:
#       employeeName
# 0   Julie Firrelli
# 1  Steve Patterson

# %% [markdown]
# ### 8. Report those payments greater than \$100,000. Sort the report so the customer who made the highest payment appears first.

# %%
run("""
select customerName, amount
from customers join payments using (customerNumber)
where amount > 100000
order by amount desc
""")
# Out:
#                    customerName     amount
# 0        Euro+ Shopping Channel  120166.58
# 1        Euro+ Shopping Channel  116208.40
# 2  Mini Gifts Distributors Ltd.  111654.40
# 3       Dragon Souveniers, Ltd.  105743.00
# 4  Mini Gifts Distributors Ltd.  101244.59

# %% [markdown]
# ### 9. List the value of 'On Hold' orders.

# %%
run("""
select orderNumber,sum(quantityOrdered*priceEach), status
from orderdetails join orders using (ordernumber)
where orders.status = 'on hold'
group by orderNumber
""")
# Out:
#    orderNumber  sum(quantityOrdered*priceEach)   status
# 0        10334                        23014.17  On Hold
# 1        10401                        43525.04  On Hold
# 2        10407                        52229.55  On Hold
# 3        10414                        50806.85  On Hold

# %%
run("""
select orderNumber,sum(quantityOrdered*priceEach), status
from orderdetails join orders using (ordernumber)
where orders.status = 'on hold'
""")
# Out:
#    orderNumber  sum(quantityOrdered*priceEach)   status
# 0        10334                       169575.61  On Hold

# %% [markdown]
# ### 10. Report the number of orders 'On Hold' for each customer.

# %%
run("""
select customerName,count(*)
from customers join orders using (customerNumber)
where status = 'on hold'
group by customerNumber
""")
# Out:
#                 customerName  count(*)
# 0   Volvo Model Replicas, Co         1
# 1    Tekni Collectables Inc.         1
# 2          Gifts4AllAges.com         1
# 3  The Sharp Gifts Warehouse         1

# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = '3306'
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user = user,
    password = password,
    db = database,
    charset = 'utf8mb4')

def run(sql):
    df=pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ### 1. List products sold by order date.

# %%
#SOLD : order yg telah dilakukan pembayaran

# %%
run("""
select productname, orderdate
from products 
join orderdetails using (productcode)
join orders using (ordernumber)
join customers using (customerNumber)
join payments using (customerNumber)
""")
#menggunakan inner join, otomatis productname yg mempunyai relasi hingga ke table payments
# Out:
#                                        productname   orderdate
# 0                                   1958 Setra Bus  2003-03-26
# 1                           1940 Ford Pickup Truck  2003-03-26
# 2                          1939 Cadillac Limousine  2003-03-26
# 3      1996 Peterbilt 379 Stake Bed with Outrigger  2003-03-26
# 4                                1968 Ford Mustang  2003-07-02
# 5                               1968 Dodge Charger  2003-07-02
# 6                          1970 Plymouth Hemi Cuda  2003-07-02
# 7                               1969 Dodge Charger  2003-07-02
# 8                      1948 Porsche 356-A Roadster  2003-07-02
# 9                             1969 Dodge Super Bee  2003-07-02
# 10                           1976 Ford Gran Torino  2003-07-02
# 11                                1957 Vespa GS150  2003-07-02
# 12                       1957 Corvette Convertible  2003-07-02
# 13                         1982 Ducati 900 Monster  2003-07-02
# ...

# %% [markdown]
# ### 2. List the order dates in descending order for orders for the 1940 Ford Pickup Truck.

# %%
run("""
select productName, orderdate
from orders 
join orderdetails using (ordernumber)
join products using (productcode)
where productName = '1940 Ford Pickup Truck' 
order by orderdate desc
""")
# Out:
#                productName   orderdate
# 0   1940 Ford Pickup Truck  2005-05-31
# 1   1940 Ford Pickup Truck  2005-05-01
# 2   1940 Ford Pickup Truck  2005-03-09
# 3   1940 Ford Pickup Truck  2005-02-17
# 4   1940 Ford Pickup Truck  2005-01-20
# 5   1940 Ford Pickup Truck  2004-12-10
# 6   1940 Ford Pickup Truck  2004-11-29
# 7   1940 Ford Pickup Truck  2004-11-18
# 8   1940 Ford Pickup Truck  2004-11-04
# 9   1940 Ford Pickup Truck  2004-10-21
# 10  1940 Ford Pickup Truck  2004-10-11
# 11  1940 Ford Pickup Truck  2004-09-08
# 12  1940 Ford Pickup Truck  2004-08-17
# 13  1940 Ford Pickup Truck  2004-07-19
# 14  1940 Ford Pickup Truck  2004-06-15
# 15  1940 Ford Pickup Truck  2004-05-04
# 16  1940 Ford Pickup Truck  2004-03-10
# 17  1940 Ford Pickup Truck  2004-01-29
# 18  1940 Ford Pickup Truck  2003-12-05
# 19  1940 Ford Pickup Truck  2003-11-25
# 20  1940 Ford Pickup Truck  2003-11-13
# 21  1940 Ford Pickup Truck  2003-11-06
# 22  1940 Ford Pickup Truck  2003-10-21
# ...

# %% [markdown]
# ### 3. List the names of customers and their corresponding order number where a particular order from that customer has a value greater than $25,000?

# %%
run("""
select customername, ordernumber , sum(quantityordered*priceeach) as total
from customers join orders using (customernumber)
join orderdetails using (ordernumber)
group by ordernumber
having total > 25000
""")
# Out:
#                      customername  ordernumber     total
# 0              Baane Mini Imports        10103  50218.95
# 1          Euro+ Shopping Channel        10104  40206.20
# 2        Danish Wholesale Imports        10105  53959.21
# 3                   Rovelli Gifts        10106  52151.81
# 4                 Cruz & Sons Co.        10108  51001.22
# 5    Motor Mint Distributors Inc.        10109  25833.14
# 6                  AV Stores, Co.        10110  48425.69
# 7       La Corne D'abondance, Co.        10114  33383.14
# 8         Dragon Souveniers, Ltd.        10117  44380.15
# 9           Salzburg Collectables        10119  35826.33
# 10     Australian Collectors, Co.        10120  45864.03
# 11           Marseille Mini Autos        10122  50824.66
# 12             Signal Gift Stores        10124  32641.98
# 13     Corrida Auto Replicas, Ltd        10126  57131.92
# 14             Muscle Machine Inc        10127  58841.35
# ...

# %% [markdown]
# ### 4. Are there any products that appear on all orders?

# %%
#jumlah order yg terjadi
run("""
select count(*) from orders
""")
# Out:
#    count(*)
# 0       326

# %%
#Jumlah kemunculan pada orderdetails.
#jumlah productname muncul/diorder
run("""
select productname, count(*)
from products join orderdetails using (productcode)
group by productcode
""")
# Out:
#                                      productname  count(*)
# 0          1969 Harley Davidson Ultimate Chopper        28
# 1                       1952 Alpine Renault 1300        28
# 2                          1996 Moto Guzzi 1100i        28
# 3           2003 Harley-Davidson Eagle Drag Bike        28
# 4                            1972 Alfa Romeo GTA        28
# 5                         1962 LanciaA Delta 16V        28
# 6                              1968 Ford Mustang        27
# 7                              2001 Ferrari Enzo        27
# 8                                 1958 Setra Bus        28
# 9                               2002 Suzuki XREO        28
# 10                            1969 Corvair Monza        27
# 11                            1968 Dodge Charger        27
# 12                              1969 Ford Falcon        27
# 13                       1970 Plymouth Hemi Cuda        27
# 14                             1957 Chevy Pickup        28
# ...

# %%
run("""
select productname, count(*) as jmlkemunculanprod
from products join orderdetails using (productcode)
group by productcode
having jmlkemunculanprod > (select count(*) from orders)
""")
# Out:
# Empty DataFrame
# Columns: [productname, jmlkemunculanprod]
# Index: []

# %%
#jumlah product pada tiap ordernumber
run("""
select ordernumber, count(*) as jmlkemunculan
from orderdetails
group by orderNumber
""")
# Out:
#      ordernumber  jmlproduk
# 0          10107         28
# 1          10103         28
# 2          10107         28
# 3          10107         28
# 4          10105         28
# 5          10103         28
# 6          10108         27
# 7          10105         27
# 8          10103         28
# 9          10107         28
# 10         10104         27
# 11         10108         27
# 12         10105         27
# 13         10108         27
# 14         10104         28
# 15         10108         27
# 16         10103         28
# 17         10109         27
# 18         10102         28
# 19         10102         28
# 20         10110         25
# 21         10106         28
# 22         10100         25
# 23         10108         27
# 24         10109         27
# 25         10104         28
# 26         10100         25
# 27         10104         28
# 28         10101         28
# 29         10103         28
# ..           ...        ...
# 79         10104         27
# ...

# %% [markdown]
# ### 5. List the names of products sold at less than 80% of the MSRP.

# %%
run("""
select productname, priceEach, MSRP
from products join orderDetails using (productcode)
where priceEach < 0.8*msrp
""")
# Out:
#                                     productname  priceEach    MSRP
# 0                         1996 Moto Guzzi 1100i      95.15  118.94
# 1                               1993 Mazda RX-7     113.23  141.54
# 2                          1937 Lincoln Berline      82.19  102.74
# 3                         1965 Aston Martin DB5      99.55  124.44
# 4                         1965 Aston Martin DB5      99.55  124.44
# 5                   1980s Black Hawk Helicopter     126.15  157.69
# 6                   1980s Black Hawk Helicopter     126.15  157.69
# 7                            1911 Ford Town Car      48.43   60.54
# 8                                P-51-D Mustang      67.58   84.48
# 9                                P-51-D Mustang      67.58   84.48
# 10                  1992 Ferrari 360 Spider red     135.47  169.34
# 11                  1992 Ferrari 360 Spider red     135.47  169.34
# 12                  1992 Ferrari 360 Spider red     135.47  169.34
# ...

# %% [markdown]
# ### 6. Reports those products that have been sold with a markup of 100% or more (i.e.,  the priceEach is at least twice the buyPrice)

# %%
run("""
SELECT productName, priceEach - buyPrice AS keuntungan, buyPrice
FROM products JOIN orderdetails
USING (productCode)
HAVING keuntungan > buyPrice
""")
# Out:
#                               productName  keuntungan  buyPrice
# 0                1952 Alpine Renault 1300      115.72     98.58
# 1                1952 Alpine Renault 1300      107.15     98.58
# 2                1952 Alpine Renault 1300      113.58     98.58
# 3                1952 Alpine Renault 1300      109.29     98.58
# 4                1952 Alpine Renault 1300      105.01     98.58
# 5                1952 Alpine Renault 1300      105.01     98.58
# 6                1952 Alpine Renault 1300      107.15     98.58
# 7                1952 Alpine Renault 1300      115.72     98.58
# 8                1952 Alpine Renault 1300      107.15     98.58
# 9                1952 Alpine Renault 1300      111.43     98.58
# 10               1952 Alpine Renault 1300      102.86     98.58
# 11               1952 Alpine Renault 1300      115.72     98.58
# 12               1952 Alpine Renault 1300      100.72     98.58
# 13               1952 Alpine Renault 1300      107.15     98.58
# ...

# %% [markdown]
# ### 7. List the products ordered on a Monday.

# %%
run("""
SELECT productName
FROM products JOIN orderdetails USING (productCode)
JOIN orders USING (orderNumber)
WHERE DAYOFWEEK(orderDate) = 2 #1:minggu, 2:senin
""")
# Out:
#                                productName
# 0    1969 Harley Davidson Ultimate Chopper
# 1    1969 Harley Davidson Ultimate Chopper
# 2    1969 Harley Davidson Ultimate Chopper
# 3    1969 Harley Davidson Ultimate Chopper
# 4    1969 Harley Davidson Ultimate Chopper
# 5    1969 Harley Davidson Ultimate Chopper
# 6                 1952 Alpine Renault 1300
# 7                 1952 Alpine Renault 1300
# 8                 1952 Alpine Renault 1300
# 9                 1952 Alpine Renault 1300
# 10                1952 Alpine Renault 1300
# 11                   1996 Moto Guzzi 1100i
# 12                   1996 Moto Guzzi 1100i
# 13                   1996 Moto Guzzi 1100i
# 14                   1996 Moto Guzzi 1100i
# 15                   1996 Moto Guzzi 1100i
# 16                   1996 Moto Guzzi 1100i
# 17                   1996 Moto Guzzi 1100i
# 18    2003 Harley-Davidson Eagle Drag Bike
# 19    2003 Harley-Davidson Eagle Drag Bike
# 20    2003 Harley-Davidson Eagle Drag Bike
# ...

# %% [markdown]
# ### 8. What is the quantity on hand for products listed on 'On Hold' orders?

# %%
run("""
SELECT productCode, status
FROM orderdetails JOIN orders USING (orderNumber)
WHERE status = 'on hold'
""")
# Out:
#    productCode   status
# 0     S10_4962  On Hold
# 1     S18_2319  On Hold
# 2     S18_2432  On Hold
# 3     S18_3232  On Hold
# 4     S18_4600  On Hold
# 5     S24_2300  On Hold
# 6     S18_2581  On Hold
# 7     S24_1785  On Hold
# 8     S24_3949  On Hold
# 9     S24_4278  On Hold
# 10    S32_1374  On Hold
# 11    S32_4289  On Hold
# 12    S50_1341  On Hold
# 13   S700_1691  On Hold
# 14   S700_2466  On Hold
# 15   S700_2834  On Hold
# 16   S700_3167  On Hold
# 17   S700_4002  On Hold
# 18    S18_1589  On Hold
# 19    S18_1749  On Hold
# 20    S18_2248  On Hold
# 21    S18_2870  On Hold
# 22    S18_4409  On Hold
# 23    S18_4933  On Hold
# 24    S24_1046  On Hold
# 25    S24_1628  On Hold
# 26    S24_2766  On Hold
# 27    S24_2887  On Hold
# 28    S24_3191  On Hold
# 29    S24_3432  On Hold
# 30    S10_4757  On Hold
# 31    S18_3029  On Hold
# 32    S18_3140  On Hold
# 33    S18_3259  On Hold
# 34    S18_4522  On Hold
# 35    S24_2011  On Hold
# 36    S24_3151  On Hold
# ...
